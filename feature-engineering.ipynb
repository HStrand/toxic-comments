# %%
import pandas as pd
import numpy as np
from nlp_pipeline import *

# %%
train = pd.read_csv('data\\train.csv').fillna(' ')
test = pd.read_csv('data\\test.csv').fillna(' ')

# %%
pretrained = 'data\\glove.840B.300d.txt'

# %%
print("Getting pretrained model from", pretrained)
vector_model = get_pretrained(pretrained)
# Out:
# Getting pretrained model from data\glove.840B.300d.txt

# %%
train = train[:10000]
test = test[:10000]

# %%
class_labels = [column for column in train.columns[2:8]]
feature_funcs = [len, asterix_freq, uppercase_freq, line_change_freq, rep_freq, question_freq]
transforms = [tokenize]
logreg = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg')
logreg.name = "Logistic regression newton"
models = [logreg]

# %%
def avg_word_length(x):
    return np.mean([len(s) for s in x.split(' ')])

# %%
pipe = NlpPipeline(train, test, "comment_text", class_labels, feature_funcs, transforms, models, word_vectors=vector_model)
print(pipe)
# Out:
# Train: (10000, 8)
# Test: (10000, 2)
# Train features: (0,)
# Test features: (0,)
# Input column: comment_text
# Class labels: toxic severe_toxic obscene threat insult identity_hate
# Models: Logistic regression newton: 30.0 balanced False True 1 100 ovr 1 l2 None newton-cg 0.0001 0 False |
# Transforms:  tokenize
# Feature functions:  function asterix_freq uppercase_freq line_change_freq rep_freq question_freq avg_word_length
# Metric: roc_auc
# CV scores: {'Logistic regression newton': -1}

# %%
pipe.run()
# Out:
# Engineering features
# Applying transforms
# Creating embeddings
# Cross-validating
# LogisticRegression(C=30.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='newton-cg', tol=0.0001, verbose=0, warm_start=False)
# Cross-validating toxic
# roc_auc: 0.9506399333511346
# Cross-validating severe_toxic
# roc_auc: 0.9118874083358671
# Cross-validating obscene
# roc_auc: 0.9578279043009091
# Cross-validating threat
# roc_auc: 0.9317573176845425
# Cross-validating insult
# roc_auc: 0.9538170169144499
# Cross-validating identity_hate
# roc_auc: 0.9371347571530688
# Fitting and predicting
# Fitting submission classifier for toxic
# Fitting submission classifier for severe_toxic
# Fitting submission classifier for obscene
# Fitting submission classifier for threat
# Fitting submission classifier for insult
# Fitting submission classifier for identity_hate
# Creating submissions

# %%
pipe.run()
# Out:
# Engineering features
# Applying transforms
# Creating embeddings
# Cross-validating
# LogisticRegression(C=30.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='newton-cg', tol=0.0001, verbose=0, warm_start=False)
# Cross-validating toxic
# roc_auc: 0.9504455588890061
# Cross-validating severe_toxic
# roc_auc: 0.9070486249195193
# Cross-validating obscene
# roc_auc: 0.9578249857951221
# Cross-validating threat
# roc_auc: 0.9357188306850641
# Cross-validating insult
# roc_auc: 0.9537063551922313
# Cross-validating identity_hate
# roc_auc: 0.9371930174270675
# Fitting and predicting
# Fitting submission classifier for toxic
# Fitting submission classifier for severe_toxic
# Fitting submission classifier for obscene
# Fitting submission classifier for threat
# Fitting submission classifier for insult
# Fitting submission classifier for identity_hate
# Creating submissions

# %%
df = pd.read_csv('submissions\\submeta.csv')

# %%
df
# Out:
#     submission                      filename  \
# 0            1   submissions\submission1.csv
# 1            2   submissions\submission2.csv
# 2            3   submissions\submission3.csv
# 3            4   submissions\submission4.csv
# 4            9   submissions\submission9.csv
# 5           10  submissions\submission10.csv
# 6           11  submissions\submission10.csv
# 7           12  submissions\submission10.csv
# 8           13  submissions\submission11.csv
# 9            7   submissions\submission7.csv
# 10           8   submissions\submission8.csv
# 11           9   submissions\submission9.csv
# 12          10  submissions\submission10.csv
# 13          11  submissions\submission11.csv
# 14          12  submissions\submission12.csv
# 15          13  submissions\submission13.csv
# 16          14  submissions\submission14.csv
# 17          15  submissions\submission15.csv
# 18          16  submissions\submission16.csv
# 19          17  submissions\submission17.csv
# 20          18  submissions\submission18.csv
#
#                                                 model pretrained  \
# 0         Logistic regression C=30 balanced newton-cg        w2v
# 1                             Logistic regression C=1        w2v
# 2         Logistic regression C=30 balanced newton-cg        w2v
# 3                             Logistic regression C=1        w2v
# 4   Logistic regression newton: 30.0 balanced Fals...        w2v
# 5   Logistic regression linear: 1.0 None False Tru...        w2v
# 6   Logistic regression newton: 30.0 balanced Fals...        w2v
# 7   Logistic regression newton: 30.0 balanced Fals...        w2v
# 8   Logistic regression newton: 30.0 balanced Fals...        w2v
# 9   Logistic regression newton: 30.0 balanced Fals...        w2v
# 10  Logistic regression newton: 30.0 balanced Fals...        w2v
# 11  Logistic regression newton: 30.0 balanced Fals...      glove
# 12  Logistic regression newton: 30.0 balanced Fals...        w2v
# 13  Logistic regression newton: 30.0 balanced Fals...        w2v
# 14  Logistic regression newton: 30.0 balanced Fals...        w2v
# 15  Logistic regression newton: 30.0 balanced Fals...      glove
# 16  XGBoost: 0.5 1 1 0 0.25 0 3 1 None 20 -1 binar...      glove
# 17  XGBoost: n_estimators=300 max_depth=5 learning...      glove
# 18  XGBoost: 0.5 1 0.6 0 0.15 0 5 1 None 300 -1 bi...      glove
# 19  Logistic regression newton: 30.0 balanced Fals...      glove
# 20  Logistic regression newton: 30.0 balanced Fals...      glove
#
#                                         feature_funcs transforms  cv_score
# 0                                            lengths   tokenize  -1.000000
# 1                                            lengths   tokenize  -1.000000
# 2                                            lengths   tokenize   0.966422
# 3                                            lengths   tokenize   0.964501
# 4                                            lengths   tokenize   0.966422
# 5                                            lengths   tokenize   0.964501
# 6                                                      tokenize   0.965800
# 7                                  lengths asterixes   tokenize   0.966697
# 8                  lengths asterixes uppercase_count   tokenize   0.966886
# 9                                                      tokenize   0.970816
# 10                                                     tokenize   0.970816
# 11                                                     tokenize   0.970816
# 12                 lengths asterixes uppercase_count   tokenize   0.708631
# 13                 lengths asterixes uppercase_count   tokenize   0.708631
# 14                 lengths asterixes uppercase_count   tokenize   0.708631
# 15                 lengths asterixes uppercase_count   tokenize   0.971778
# 16                 lengths asterixes uppercase_count   tokenize   0.951007
# 17                 lengths asterixes uppercase_count   tokenize   0.976536
# 18                 lengths asterixes uppercase_count   tokenize   0.976536
# 19  function asterix_freq uppercase_freq line_chan...  tokenize   0.940511
# 20  function asterix_freq uppercase_freq line_chan...  tokenize   0.940323
